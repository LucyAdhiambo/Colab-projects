# %% [markdown]
# <a href="https://colab.research.google.com/github/LucyAdhiambo/Colab-projects/blob/main/WEEKLY_SALES_COMPARISON_FRM_WK_27_WK34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Data
weeks = ["Week 27", "Week 28", "Week 29", "Week 30", "Week 31", "Week 32","Week 33"]
doses = [49, 73, 80, 78, 90, 75, 71]
target = 80

# Assign colors: jungle green if >= target, bright red if < target
colors = ["#29AB87" if d >= target else "#FF3131" for d in doses]
# Jungle green = #29AB87, Bright red = #FF3131

# Add values on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # X position (center of bar)
        height + 1,                         # Y position (slightly above bar)
        f"{height}",                        # Text label
        ha="center", va="bottom", fontsize=10
    )
# Plot bars
plt.figure(figsize=(8, 5))
bars = plt.bar(weeks, doses, color=colors, label="Weekly Doses")

# Add target line (with label so it appears in the key)
plt.axhline(y=target, color="black", linestyle="--", linewidth=1, label=f"Target = {target}")

# Labels and title
plt.title("Weekly Doses vs Target", fontsize=14)
plt.xlabel("Week", fontsize=12)
plt.ylabel("Number of Doses", fontsize=12)

# Show legend (key)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-399739841.py in <cell line: 0>()
#      11
#      12 # Add values on top of bars
# ---> 13 for bar in bars:
#      14     height = bar.get_height()
#      15     plt.text(
#
# NameError: name 'bars' is not defined

# %%
import matplotlib.pyplot as plt

# Data
weeks = ["Week 27", "Week 28", "Week 29", "Week 30", "Week 31", "Week 32", "Week 33","Week 34"]
doses = [49, 73, 80, 78, 90, 75, 71,80]
target = 80

# Assign colors: jungle green if >= target, bright red if < target
colors = ["#29AB87" if d >= target else "#FF3131" for d in doses]
# Jungle green = #29AB87, Bright red = #FF3131

# Plot bars
plt.figure(figsize=(8, 5))
bars = plt.bar(weeks, doses, color=colors, label="Weekly Doses")

# Add target line (with label so it appears in the key)
plt.axhline(y=target, color="black", linestyle="--", linewidth=1, label=f"Target = {target}")

# Add values on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # X position (center of bar)
        height + 1,                         # Y position (slightly above bar)
        f"{height}",                        # Text label
        ha="center", va="bottom", fontsize=10
    )

# Labels and title
plt.title("Weekly Doses vs Target", fontsize=14)
plt.xlabel("Week", fontsize=12)
plt.ylabel("Number of Doses", fontsize=12)

# Show legend (key)
plt.legend()

plt.show()
