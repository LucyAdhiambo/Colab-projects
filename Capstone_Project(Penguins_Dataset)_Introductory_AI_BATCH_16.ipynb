# %% [markdown]
# <a href="https://colab.research.google.com/github/LucyAdhiambo/Colab-projects/blob/main/Capstone_Project(Penguins_Dataset)_Introductory_AI_BATCH_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ARTIFICIAL INTELLIGENCE INTRODUCTORY PROGRAMME
# ### CAPSTONE PROJECT(Penguins_dataset)
# ### BATCH_16
# #### Prepared by_Lucy Adhiambo Akula
# ###### Date.18/3/2025.

# %% [markdown]
# ### Problem Statement.
# #### In this project, you would explore the Data preprocessing techniques learned. You will
# #### use, pandas, plots and the different data preprocessing techniques to explore and
# #### analyse the data. This project is on Exploratory Data Analysis.

# %% [markdown]
# ##### Import the necessary libraries.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ##### List the set of available datasets in seaborn.

# %%
##### List the set of available datasets in seaborn
print(len(sns.get_dataset_names()))
print(sns.get_dataset_names())
# Out:
# 22
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# ###### Dataset : exercise.

# %%
#1.Write the syntax for choosing the specific dataset
df = sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
#2.Display the top 5 records of penguin dataset
print(df.head(5))
#3.Display the dimensionality of the dataset
df.shape
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# (344, 7)

# %%
#4.Display the datatypes of the attributes
df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
print(df['species'].unique())
print(df['species'].nunique())
# Out:
# ['Adelie' 'Chinstrap' 'Gentoo']
# 3

# %%
print(df['island'].unique())
print(df['island'].nunique())
# Out:
# ['Torgersen' 'Biscoe' 'Dream']
# 3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
##### 5.Describe the dataset extensively.

# %% [markdown]
# ##### The data is a penguines dataset, describing three penguin species-'Adelie','Chinstrap'&'Gentoo'
# ##### in 3 different Islands 'Torgersen','Biscoe' 'Dream'. Other features like their 'bill_length_mm',
# ##### 'bill_depth_mm','flipper_length_mm',
# ##### 'body_mass_g' and 'sex' have also been given.'bill_length_mm','bill_depth_mm',
# ##### 'flipper_length_mm'and 'body_mass_g', and sex
# ##### have missing values. In order to have a complete and unbiased dataset,
# ##### we will either replace the missing values
# ##### with a mean or do away with them, as they are not that many and their impact will be insignificant.

# %%
### Converting object data type to Category

# %%
df['species']=df['species'].astype('category')
df['island']=df['island'].astype('category')
df['sex']=df['sex'].astype('category')

# %%
df.dtypes
# Out:
# species              category
# island               category
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                  category
# dtype: object

# %%
#6.Display the number of null values in the dataset and the total count of it
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
### 7.Identify the columns having null values and remove them....

# %%
##### The syntax for identifying null_columns and
##### removing them is as below, but removing
##### all the columns with null value will leave us with
##### only 2 columns, which is 'species'&'island'
##### this will make it impossible to work with the dataset,
##### therefore: Removing rows with null value,
##### will make more sense and will allow us to still work on the dataset
null_columns=df.columns[df.isnull().any()]
print('Columns with null values',null_columns)
df1=df.drop(columns=null_columns)
print(df1)
# Out:
# Columns with null values Index(['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g',
#        'sex'],
#       dtype='object')
#     species     island
# 0    Adelie  Torgersen
# 1    Adelie  Torgersen
# 2    Adelie  Torgersen
# 3    Adelie  Torgersen
# 4    Adelie  Torgersen
# ..      ...        ...
# 339  Gentoo     Biscoe
# 340  Gentoo     Biscoe
# 341  Gentoo     Biscoe
# 342  Gentoo     Biscoe
# 343  Gentoo     Biscoe
#
# [344 rows x 2 columns]

# %%
total_missing=df.isnull().sum().sum()
print(total_missing)
# Out:
# 0

# %%
df1.shape
# Out:
# (344, 2)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   species  344 non-null    category
#  1   island   344 non-null    category
# dtypes: category(2)
# memory usage: 1.1 KB

# %%
df1.isna().sum().sum()
# Out:
# 0

# %%
# 8.check the size of dataset after cleaning and compare with
# the size before cleaning.

# %% [markdown]
# #### Observations.

# %% [markdown]
# ##### After cleaning, the size of the dataset reduced tremendously
# ##### from 344 rows and 7 columns, to 344 rows and 2 columns.
# ##### Dropping the columns, reduced the quantity of our dataset,
# ##### leaving only two columns,'species' & 'island', as they
# ##### had no null values.

# %%
# 7a. Alternatively,Identify the rows having null values and remove them,....
df=sns.load_dataset('penguins')
print(df)
df.head(5)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
### identify the rows with null values
null_row =df[df.isnull().any(axis=1)]
print(null_row)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 246  Gentoo     Biscoe            44.5           14.3              216.0
# 286  Gentoo     Biscoe            46.2           14.4              214.0
# 324  Gentoo     Biscoe            47.3           13.8              216.0
# 336  Gentoo     Biscoe            44.5           15.7              217.0
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 8         3475.0  NaN
# ...

# %%
print(df.isnull().any(axis=1))
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 339     True
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
### Removes the rows with null values.
df.dropna(axis=0,inplace=True)
print(df)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.shape
# Out:
# (333, 7)

# %%
# 8.Check the size of dataset after cleaning and compare
# with the size before cleaning.

# %% [markdown]
# #### Observations.

# %% [markdown]
# ##### Initially, the number of rows were 344 and 7 columns ,
# ##### but after cleaning i.e removing the null values it reduced to 333 and 7 columns.

# %%
#9.Find out the count of male and female penguins

# %%
gender_count=df['sex'].value_counts()
print(gender_count)
# Out:
# sex
# Male      168
# Female    165
# Name: count, dtype: int64

# %% [markdown]
# ##### Observations
# ###### There are more males than Female penguins by 3.

# %%
##### 10 Find out the count of species

# %%
species_count=df['species'].value_counts()
print(species_count)
# Out:
# species
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# ###### Observations
# ###### The Adelie penguin species is the most common, followed by Gentoo then Chinstrap.

# %%
#11. Use a countplot graph to display the number of male and female penguins
#### Give the plot a title "Count of male and female penguins"
#### Give a xlabel and ylabel

# %%
plt.figure(figsize=(6,3))
plt.title('Count of male and female penguins')
sns.countplot(x='sex', data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### Observations.
# ##### The count plot allows us to visualize the distribution of the
# ##### female and male penguins polulation in the penguins dataset.
# ##### From the count plot, we can see that the two sexes are evely distributed.

# %%
##### 12. For all the penguins display the bill_length_mm and
#### bill_depth_mm using a pairplot.

# %%
sns.pairplot(df,vars=['bill_length_mm', 'bill_depth_mm'], hue='species')
plt.show()

# %% [markdown]
# #### Observations
# ##### The pairplot is a very powerful visualization tool, in that it compares
# ##### two or more numeric values to show how they relate to each other,
# ##### spot patterns and separates them into categories using scatter plot and Histogram.
# ##### Its a great way to observe the relationship between multiple numeric values in a dataset.
# ##### From the pairplot outcome, the Species,'Adelie' clusters around short but thick bill,
# ##### while'Gentoo' clusters around longer and less thicker bill while 'Chinstrap' is in-between.

# %%
#13.Create a visualization to display the flipper_length_mm and body_mass_g for
### the pinguen dataset.

# %%
plt.figure(figsize=(6,3))
plt.title('flipper_length_mm and body_mass_g')
sns.scatterplot(data=df,x='flipper_length_mm',y='body_mass_g',hue='species')
xlabel='flipper_length_mm'
ylabel='body_mass_g'
plt.show()

# %% [markdown]
# ##### Obsevations
# ##### Scatter plot is another visualization tool,suitable when dealing with two or more numeric variables.
# ##### To interpret the relationship-each dot represents a penguin. The 'Adelie' species has a lower body_mass
# ##### and shorter flippers.'Gentoo' species are heavier and in-turn have longer flipper and 'Chinstrap' are in-between.
# ##### thus their is a linear relation between flipper_length and body_mass i.e there is a correlation.

# %%
#14. Create a histogram with the flipper_length_mm and bins = 10

# %%
sns.histplot(data=df,x='flipper_length_mm',bins=10)
plt.title('Hist of flipper_length_mm')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Observations

# %% [markdown]
# ##### The flipper_length of the penguins across all the species ranges between 185mm-220mm,
# ##### with one specific species having a very long Flipper_length of between 190mm-195mm thus
# ##### giving a noticeable range of difference from the rest.
# ##### Histograms are a great tool for data visualization especially when its a sinlge varible.
# ##### They assist in detecting skewedness i.e is the data left_skewed,
# ##### right_skewed or symmetric, as the above hist.It also makes it possible to analyse a single variable
# ##### more easily and clearer.
# ##### Histograms will help detect outliers.

# %%
#15. Create a joint plot with bill_length_mm, bill_depth_mm for penguins_cleaned dataset.

# %%
sns.jointplot(data=df,x='bill_length_mm',y='bill_depth_mm',kind='scatter',hue='species')
plt.title('Jointplot of bill_length and bill_depth',fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.jointplot(data=df,x='bill_length_mm',y='bill_depth_mm',kind='kde')
plt.title('Jointplot of bill_length vs bill_depth',fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.jointplot(data=df,x='bill_length_mm',y='bill_depth_mm',kind='reg',)
plt.title('Jointplot of bill_length vs bill_depth',fontsize=12)
plt.tight_layout()
plt.show()

# %%
sns.jointplot(data=df,x='bill_length_mm',y='bill_depth_mm',kind='hex')
plt.title('Jointplot of bill_length vs bill_depth',fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Observations

# %% [markdown]
# ##### The joint plot is another visualization tool in seaborn, used for showing the
# ##### relation between two variables at the sametime in a combined, scatter plot
# ##### and histogram for a more insighful observations.
# ##### In the relationship, between the bill_length and the bill_depth,
# ##### it shows a No linear relatioship,because,between bill_length and depth,as
# ##### some species have a thicker bill but shorter length('Adelie'),'Gentoo' is longer and less thick,
# ##### while 'Chinstrap' is in-between.

# %%
#### 16.Use a pairwise plot to display all the numerical values of the dataset penguins_cleaned.

# %%
sns.pairplot(df,hue='species',height=1.5,aspect=1)
plt.show()

# %% [markdown]
# #### Observations

# %% [markdown]
# ##### A pairplot displays all the numeric values in the data set, and its a powerful
# ##### visualization tool in seaborn to compare all the numeric variables in th dataset.
# ##### In the penguins dataset, the pairplot reveales how the species 'Adelie' and 'Chinstrap' tend
# ##### to have related body features, while 'Gentoo' has far distict features from the rest.

# %%
#### 17.Check if there exists any outliers based on the boxplot based on numerical
#### values of the dataset peguines cleaned.

# %%
sns.boxplot(data=df,y='bill_length_mm')
plt.show()

# %%
sns.boxplot(data=df,y='flipper_length_mm')
plt.show()

# %%
sns.boxplot(data=df,y='body_mass_g')
plt.show()

# %%
sns.boxplot(data=df,y='bill_depth_mm')
plt.show()

# %% [markdown]
# #### Observations.

# %% [markdown]
# ##### From the box plots analysis, there are No outliers throughout the features in the data set,
# ##### even after performing the Interquater range method the data still remained at 333.

# %%
#### 18. Create a violin plot to display the body_mass_g of different species based on sex

# %%
sns.violinplot(data=df,x='sex',y='body_mass_g')
plt.show()

# %% [markdown]
# #### Observations.

# %% [markdown]
# ##### Violin plot is a powerful visualization tool in seaborn, that is used to
# ##### compare distribution and  detect differences in shape in different varibles.
# ##### In the dataset, the Female penguins are lighter compared to the male,
# ##### their weight is more concentrated between 3000-4000 body_mass_g, while males are
# ##### between 4000-5000 body_mass_g.

# %% [markdown]
# # THE END OF THE CAPSTONE PROJECT(AI BATCH-16).
